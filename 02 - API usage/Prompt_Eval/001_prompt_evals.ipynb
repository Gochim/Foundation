# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
dataset = generate_dataset()

with open('dataset.json', 'w') as f:
    json.dump(dataset, f, indent=2)

# %%
def run_prompt(test_case):
    """Merges the prompt and test case input, then returns the result"""
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""
    
    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)
    
    # TODO - Grading
    score = 10
    
    return {
        "output": output,
        "test_case": test_case,
        "score": score
    }

# %%
def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []
    
    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)
    
    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)

print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# AWS S3 Bucket Naming Validator\n\n```python\nimport re\n\ndef is_valid_s3_bucket_name(bucket_name: str) -> bool:\n    \"\"\"\n    Validates if a bucket name follows AWS S3 naming conventions.\n    \n    AWS S3 bucket naming rules:\n    - Must be between 3 and 63 characters long\n    - Must start and end with a lowercase letter or number\n    - Can contain lowercase letters, numbers, and hyphens\n    - Cannot contain uppercase letters or underscores\n    - Cannot be formatted as an IP address (e.g., 192.168.1.1)\n    \n    Args:\n        bucket_name: The S3 bucket name to validate\n        \n    Returns:\n        True if the bucket name is valid, False otherwise\n    \"\"\"\n    # Check if bucket_name is a string\n    if not isinstance(bucket_name, str):\n        return False\n    \n    # Check length (3-63 characters)\n    if len(bucket_name) < 3 or len(bucket_name) > 63:\n        return False\n    \n    # Check for uppercase letters or underscores\n    if bucket_name != bucket_name.lower() or '_' in bucket_name:\n        return False\n    \n    # Check if it starts and ends with lowercase letter or number\n    if not (bucket_name[0].isalnum() and bucket_name[-1].isalnum()):\n        return False\n    \n    # Check if it only contains lowercase letters, numbers, and hyphens\n    if not re.match(r'^[a-z0-9-]+$', bucket_name):\n        return False\n    \n    # Check for consecutive hyphens (optional but good practice)\n    if '--' in bucket_name:\n        return False\n    \n    # Check if it's formatted as an IP address\n    if re.match(r'^\\d+\\.\\d+\\.\\d+\\.\\d+$', bucket_name):\n        return False\n    \n    return True\n\n\n# Test cases\nif __name__ == \"__main__\":\n    test_cases = [\n        # Valid bucket names\n        (\"my-bucket\", True),\n        (\"my-bucket-123\", True),\n        (\"bucket123\", True),\n        (\"a\" * 63, True),  # Maximum length\n        (\"abc\", True),  # Minimum length\n        \n        # Invalid bucket names\n        (\"My-Bucket\", False),  # Contains uppercase\n        (\"my_bucket\", False),  # Contains underscore\n        (\"my--bucket\", False),  # Consecutive hyphens\n        (\"ab\", False),  # Too short (less than 3)\n        (\"a\" * 64, False),  # Too long (more than 63)\n        (\"-mybucket\", False),  # Starts with hyphen\n        (\"mybucket-\", False),  # Ends with hyphen\n        (\"192.168.1.1\", False),  # IP address format\n        (\"my.bucket\", False),  # Contains dot\n        (\"\", False),  # Empty string\n        (\"my bucket\", False),  # Contains space\n        (None, False),  # Not a string\n        (123, False),  # Not a string\n    ]\n    \n    print(\"AWS S3 Bucket Name Validation Tests:\\n\")\n    for bucket_name, expected in test_cases:\n        result = is_valid_s3_bucket_name(bucket_name)\n        status = \"\u2713\" if result == expected else \"\u2717\"\n        print(f\"{status} is_valid_s3_bucket_name({bucket_name!r}) = {result} (expected {expected})\")\n```\n\n**Output:**\n```\nAWS S3 Bucket Name Validation Tests:\n\n\u2713 is_valid_s3_bucket_name('my-bucket') = True (expected True)\n\u2713 is_valid_s3_bucket_name('my-bucket-123') = True (expected True)\n\u2713 is_valid_s3_bucket_name('bucket123') = True (expected True)\n\u2713 is_valid_s3_bucket_name('aaa...aaa') = True (expected True)\n\u2713 is_valid_s3_bucket_name('",
#     "test_case": {
#       "task": "Write a Python function that takes an AWS S3 bucket name and returns True if it follows AWS naming conventions (lowercase, 3-63 characters, no underscores), False otherwise."
#     },
#     "score": 10
#   },
#   {
#     "output": "# AWS IAM Policy for S3 Read-Only Access\n\nHere's a JSON object representing an AWS IAM policy for read-only access to a specific S3 bucket:\n\n```json\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Sid\": \"ListBucketContents\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:ListBucket\",\n        \"s3:GetBucketLocation\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-data-bucket\"\n    },\n    {\n      \"Sid\": \"ReadObjectsInBucket\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetObject\",\n        \"s3:GetObjectVersion\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-data-bucket/*\"\n    }\n  ]\n}\n```\n\n## Policy Explanation\n\n| Component | Description |\n|-----------|-------------|\n| **Version** | Policy language version (2012-10-17 is current) |\n| **ListBucketContents** | Allows listing bucket contents and viewing bucket location |\n| **ReadObjectsInBucket** | Allows reading/downloading objects and their versions |\n| **Resource ARNs** | Specifies the bucket itself and all objects within it |\n\n## To Attach to a Principal\n\nIf you need to attach this as a role trust policy or user policy, use:\n\n```json\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Effect\": \"Allow\",\n      \"Principal\": {\n        \"AWS\": \"arn:aws:iam::123456789012:user/username\"\n      },\n      \"Action\": \"sts:AssumeRole\"\n    }\n  ]\n}\n```\n\n**Replace `arn:aws:iam::123456789012:user/username`** with your actual principal ARN.",
#     "test_case": {
#       "task": "Create a JSON object that represents an AWS IAM policy allowing read-only access to a specific S3 bucket named 'my-data-bucket' for a principal ARN."
#     },
#     "score": 10
#   },
#   {
#     "output": "# AWS EC2 Instance ID Regular Expression\n\n```regex\n^i-[0-9a-f]{17}$\n```\n\n## Explanation\n\n| Component | Meaning |\n|-----------|---------|\n| `^` | Start of string (anchor) |\n| `i-` | Literal \"i-\" prefix (required for all EC2 instance IDs) |\n| `[0-9a-f]` | Character class matching any hexadecimal digit (0-9, a-f) |\n| `{17}` | Exactly 17 characters from the character class |\n| `$` | End of string (anchor) |\n\n## Examples\n\n**Valid matches:**\n- `i-0a1b2c3d4e5f6g7h8` \u274c (contains 'g', not hex)\n- `i-0a1b2c3d4e5f67890` \u2705\n- `i-1234567890abcdef0` \u2705\n\n**Invalid matches:**\n- `i-0a1b2c3d4e5f6789` \u274c (only 16 hex characters)\n- `i-0a1b2c3d4e5f678901` \u274c (18 hex characters)\n- `0a1b2c3d4e5f67890` \u274c (missing \"i-\" prefix)\n\n## Case Insensitive Version\n\nIf you need to match uppercase letters as well:\n\n```regex\n^i-[0-9a-fA-F]{17}$\n```\n\nOr with the case-insensitive flag (language-dependent):\n```regex\n^i-[0-9a-f]{17}$  # with /i flag in most languages\n```",
#     "test_case": {
#       "task": "Write a regular expression that matches valid AWS EC2 instance IDs (format: i- followed by 17 hexadecimal characters)."
#     },
#     "score": 10
#   }
# ]
